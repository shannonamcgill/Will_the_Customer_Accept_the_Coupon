# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.info();
# first steps are to review the data types and and check for missing values 
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
#dropping the car data

# %%
data = data.drop('car', axis=1)

# %%
data.head()
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  Bar                   12577 non-null  object
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
print('Because 99% of the car values were null I decided to remove the car attribute from the population.')
# Out:
# Because 99% of the car values were null I decided to remove the car attribute from the population.

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
total_accept_rate = data[data['Y']==1].count()[0]/data.count()[0]
print(total_accept_rate)
# Out:
# 0.5684326710816777

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
coupon_data = data["coupon"].value_counts().to_frame()
coupon_data.info
# Out:
# <bound method DataFrame.info of                        count
# coupon
# Coffee House            3996
# Restaurant(<20)         2786
# Carry out & Take away   2393
# Bar                     2017
# Restaurant(20-50)       1492>

# %%
sns.barplot(coupon_data, x=coupon_data.index, y = 'count')
plt.title('Distribution of Coupons')
plt.xlabel('')
plt.ylabel('Distributed Number of Coupons')
plt.xticks(rotation = 45)
plt.savefig('images/Distributed_Number_of_Coupons_Barchart.png')

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
fig = px.histogram(data, x="temperature", title='Temperature Day Coupon was Given', color='Y')
fig.show()
fig.write_image('images/Histogram_of_Temperature.png')
# Out:
# <div>                            <div id="e830b649-9880-47a4-b820-24d81fbbd462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e830b649-9880-47a4-b820-24d81fbbd462")) {                    Plotly.newPlot(                        "e830b649-9880-47a4-b820-24d81fbbd462",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Y=1<br>temperature=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":[55,80,80,55,80,80,80,55,55,55,55,55,80,80,55,55,80,80,80,55,55,55,80,55,55,80,80,80,80,80,80,55,55,55,80,55,80,80,80,80,80,55,80,80,80,80,55,55,80,55,80,55,80,80,80,80,80,80,80,80,80,55,55,55,55,55,80,55,80,80,55,55,
# ...

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
data['coupon'].value_counts()
# Out:
# coupon
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: count, dtype: int64

# %%
data_bar= data.query('coupon =="Bar"').dropna(subset=['Bar'])
data_bar.count()[0]
# Out:
# 1996

# %%
data_bar['Bar'].value_counts()
# Out:
# Bar
# never    830
# less1    570
# 1~3      397
# 4~8      150
# gt8       49
# Name: count, dtype: int64

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_count = data_bar.count()[0]
data_bar_Y =data_bar.query('Y==1')
data_bar_Y_count = data_bar_Y.count()[0]
bar_total_accept_rate = data_bar_Y_count/bar_count
print(f'{bar_total_accept_rate} of bar coupons were accepted')
# Out:
# 0.4103206412825651 of bar coupons were accepted

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
#calculate the acceptance rate of those who went to a bar 3 or fewer times 
data_bar_3_less = data_bar[data_bar['Bar'].isin(['less1','1~3'])].count()[0]
data_bar_3_less_Y = data_bar_Y[data_bar_Y['Bar'].isin(['less1','1~3'])].count()[0]
data_bar_3_less_accept_rate = data_bar_3_less_Y/data_bar_3_less


#calculate the acceptance rate of those who went to a bar more than 3 times 
data_bar_3_more = data_bar[data_bar['Bar'].isin(['4~8','gt8'])].count()[0]
data_bar_3_more_Y = data_bar_Y[data_bar_Y['Bar'].isin(['4~8','gt8'])].count()[0]
data_bar_3_more_accept_rate = data_bar_3_more_Y/data_bar_3_more


print(f'The acceptance rate of those that went to the bar 3 or fewer times is: {data_bar_3_less_accept_rate}')
print(f'The acceptance rate of those that went to the bar more than 3 times is: {data_bar_3_more_accept_rate}')
print(f'There is a {data_bar_3_more_accept_rate-data_bar_3_less_accept_rate} greater chance of accepting the coupon when customers vist the bar more than 3 times a month.')
# Out:
# The acceptance rate of those that went to the bar 3 or fewer times is: 0.5274043433298863
# The acceptance rate of those that went to the bar more than 3 times is: 0.7688442211055276
# There is a 0.24143987777564135 greater chance of accepting the coupon when customers vist the bar more than 3 times a month.

# %%
bar_graph_data = [['More than 3',  data_bar_3_more_accept_rate], ['3 or less', data_bar_3_less_accept_rate]]
 
# Create the pandas DataFrame
bar_graph_df = pd.DataFrame(bar_graph_data, columns=['Number of Bar Vists', 'Acceptance Rate'])
fig = px.bar(bar_graph_df, x='Number of Bar Vists',y='Acceptance Rate',title = 'Coupon Acceptance Rate for Number of Bar Visits')
fig.show()
fig.write_image('images/Coupon_Acceptance_Rate_for_Number_of_Bar_Visits.png')
# Out:
# <div>                            <div id="cc7b76af-7dd1-4137-9375-fbc27eaedb16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc7b76af-7dd1-4137-9375-fbc27eaedb16")) {                    Plotly.newPlot(                        "cc7b76af-7dd1-4137-9375-fbc27eaedb16",                        [{"alignmentgroup":"True","hovertemplate":"Number of Bar Vists=%{x}<br>Acceptance Rate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["More than 3","3 or less"],"xaxis":"x","y":[0.7688442211055276,0.5274043433298863],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcon
# ...

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
data_bar['age'].value_counts()
# Out:
# age
# 21         416
# 26         392
# 31         334
# 50plus     281
# 36         206
# 41         171
# 46         109
# below21     87
# Name: count, dtype: int64

# %%
#creating a lists of filters 
more_than_once_list= ['gt8','gt8','1~3']
below21_list = ['21','below21' ]

# acceptance rate of drivers who go to a bar more than once a month and are over the age of 25  
bar_over25 = data_bar.query("(Bar in @more_than_once_list & age not in @below21_list)").count()[0]
bar_over25Y = data_bar.query("(Bar in @more_than_once_list & age not in @below21_list & Y==1)").count()[0]

bar_over25Y_accept_rate = bar_over25Y/ bar_over25
print(f'People over the age of 25 and frequenting the bar more than once a month had an acceptance rate of: {round(bar_over25Y_accept_rate,2)}')

# acceptance rate of everyone else
bar_else = data_bar.query("(Bar not in @more_than_once_list & age in @below21_list)").count()[0]
bar_elseY = data_bar.query("(Bar not in @more_than_once_list & age in @below21_list & Y==1)").count()[0]

bar_else_accept_rate = bar_elseY/ bar_else
print(f'Everyone else had an acceptance rate of : {round(bar_else_accept_rate,2)}')
print(f'People in the over 25 population were {round((bar_over25Y_accept_rate-bar_else_accept_rate)*100,2)}% more likely to accept the coupon.')
# Out:
# People over the age of 25 and frequenting the bar more than once a month had an acceptance rate of: 0.66
# Everyone else had an acceptance rate of : 0.44
# People in the over 25 population were 22.58% more likely to accept the coupon.

# %%
#graphing the data 
bar_graph_data4 = [['Over 25',  bar_over25Y_accept_rate], ['Everyone else', bar_else_accept_rate]]
 
# Create the pandas DataFrame
bar_graph_df = pd.DataFrame(bar_graph_data4, columns=['Bar Customer Segmentation', 'Acceptance Rate'])
fig = px.bar(bar_graph_df, x='Bar Customer Segmentation',y='Acceptance Rate',title = 'Bar Customer Segmentation Number of Bar Visits')
fig.show()
fig.write_image('images/q4_Bar_Customer_Segmentation_for_Number_of_Bar_Visits.png')
# Out:
# <div>                            <div id="c8f5fa50-11b2-4e22-a726-4e7c07ba33f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8f5fa50-11b2-4e22-a726-4e7c07ba33f6")) {                    Plotly.newPlot(                        "c8f5fa50-11b2-4e22-a726-4e7c07ba33f6",                        [{"alignmentgroup":"True","hovertemplate":"Bar Customer Segmentation=%{x}<br>Acceptance Rate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Over 25","Everyone else"],"xaxis":"x","y":[0.6624203821656051,0.4366576819407008],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogra
# ...

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
data_bar['passanger'].value_counts()
data_bar['occupation'].value_counts()
data_bar['Bar'].value_counts()
data_bar.count()
# Out:
# destination             1996
# passanger               1996
# weather                 1996
# temperature             1996
# time                    1996
# coupon                  1996
# expiration              1996
# gender                  1996
# age                     1996
# maritalStatus           1996
# has_children            1996
# education               1996
# occupation              1996
# income                  1996
# Bar                     1996
# CoffeeHouse             1966
# CarryAway               1981
# RestaurantLessThan20    1982
# Restaurant20To50        1969
# toCoupon_GEQ5min        1996
# toCoupon_GEQ15min       1996
# toCoupon_GEQ25min       1996
# direction_same          1996
# direction_opp           1996
# Y                       1996
# dtype: int64

# %%
#acceptance rate for drivers who go to bars more than once a 
#month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry
dataset1 = data_bar[(~data_bar['passanger'].isin(['Kid(s)']))  
                    & (~data_bar['occupation'].isin(['Farming Fishing & Forestry']))
                    &(~data_bar['Bar'].isin(['never','less1'])) ]

#determing number of  
q5_1 = dataset1.count()[0]
q5_1Y = dataset1[(dataset1['Y']==1)].count()[0]
q5_1_accept_rate = q5_1Y/q5_1
print(f'People in the first population had an acceptance rate of: {round(q5_1_accept_rate,2)}')

dataset2 = data_bar[(data_bar['passanger'].isin(['Kid(s)']))  
                    & (data_bar['occupation'].isin(['Farming Fishing & Forestry']))
                    &(data_bar['Bar'].isin(['never','less1'])) ]

q5_2 = dataset2.count()[0]
q5_2Y = dataset2[(dataset2['Y']==1)].count()[0]
q5_2_accept_rate = q5_2Y/q5_2
print(f'People in the second population had an acceptance rate of: {round(q5_2_accept_rate,2)}')
print(f'People in the first population were {round((q5_1_accept_rate-q5_2_accept_rate)*100,2)}% more likely to accept the coupon.')
# Out:
# People in the first population had an acceptance rate of: 0.71
# People in the second population had an acceptance rate of: 0.33
# People in the first population were 37.99% more likely to accept the coupon.

# %%
#graphing the data 
bar_graph_data5 = [['First Population',  q5_1_accept_rate], ['Second ', q5_2_accept_rate]]
 
# Create the pandas DataFrame
bar_graph_df = pd.DataFrame(bar_graph_data5, columns=['Bar Customer Segmentation', 'Acceptance Rate'])
fig = px.bar(bar_graph_df, x='Bar Customer Segmentation',y='Acceptance Rate',title = 'Acceptance Rate of Customer Segmentation')
fig.update_traces(marker_color='green')
fig.show()
fig.write_image('images/q5_Bar_Customer_Segmentation2.png')
# Out:
# <div>                            <div id="bee23df0-f6ad-4736-b4ae-7c0550650427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bee23df0-f6ad-4736-b4ae-7c0550650427")) {                    Plotly.newPlot(                        "bee23df0-f6ad-4736-b4ae-7c0550650427",                        [{"alignmentgroup":"True","hovertemplate":"Bar Customer Segmentation=%{x}<br>Acceptance Rate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"green","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["First Population","Second "],"xaxis":"x","y":[0.7132486388384754,0.3333333333333333],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogr
# ...

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
data_bar['age'].value_counts()
# Out:
# age
# 21         416
# 26         392
# 31         334
# 50plus     281
# 36         206
# 41         171
# 46         109
# below21     87
# Name: count, dtype: int64

# %%
#acceptance rate for drivers who go to bars more than once a 
#month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry
q6_dataset1 = data_bar[(
                    # go to bars more than once a month, had passengers that were not a kid, and were not widowed 
                        (
                        ~data_bar['Bar'].isin(['never','less1']) 
                        & ~data_bar['passanger'].isin(['Kid(s)']) 
                        & ~data_bar['maritalStatus'].isin(['Widowed'])
                       )
                        | #or  
                          # go to bars more than once a month and are under the age of 30 *OR*
                       (
                         ~data_bar['Bar'].isin(['never','less1']) 
                        & ~data_bar['age'].isin(['31','50plus','36','41','46'])
                        )
                        | # 
                      #go to cheap restaurants more than 4 times a month and income is less than 50K. 
                        (
                         ~data_bar['RestaurantLessThan20'].isin(['never','1~3']) 
                        & ~data_bar['income'].isin(['$50000 - $62499','$62500 - $74999','$75000 - $87499', 
                                                    '$87500 - $99999','$62500 - $74999','$100000 or More'])
                        )
                    )]

q6_1 = q6_dataset1.count()[0]

q6_1Y = q6_dataset1[(q6_dataset1['Y']==1)].count()[0]
q6_1_accept_rate = q6_1Y/q6_1

# %%
#acceptance rate for drivers who go to bars more than once a 
#month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry
q6_dataset2 = data_bar[(
                    # do not go to bars more than once a month, had passengers that were not a kid, and were not widowed 
                        (
                        data_bar['Bar'].isin(['never','less1']) 
                        & data_bar['passanger'].isin(['Kid(s)']) 
                        & data_bar['maritalStatus'].isin(['Widowed'])
                       )
                        | #or  
                          # go to bars more than once a month and are under the age of 30 *OR*
                       (
                          data_bar['Bar'].isin(['never','less1']) 
                        & data_bar['age'].isin(['31','50plus','36','41','46'])
                        )
                        | # 
                      #go to cheap restaurants more than 4 times a month and income is less than 50K. 
                        (
                           data_bar['RestaurantLessThan20'].isin(['never','1~3']) 
                        &  data_bar['income'].isin(['$50000 - $62499','$62500 - $74999','$75000 - $87499', 
                                                    '$87500 - $99999','$62500 - $74999','$100000 or More'])
                        )
                    )]

q6_2 = q6_dataset2.count()[0]

q6_2Y = q6_dataset2[(q6_dataset2['Y']==1)].count()[0]
q6_2_accept_rate = q6_2Y/q6_2
print(f'People in the first population had an acceptance rate of: {round(q6_1_accept_rate,2)}')
print(f'People in the first population had an acceptance rate of: {round(q6_2_accept_rate,2)}')
print(f'People in the first population were {round((q6_1_accept_rate-q6_2_accept_rate)*100,2)}% more likely to accept the coupon.')
# Out:
# People in the first population had an acceptance rate of: 0.55
# People in the first population had an acceptance rate of: 0.31
# People in the first population were 24.09% more likely to accept the coupon.

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?
#
# **Hypothesise**
#
# I observe that the most significant influence on people who accept coupons is how frequently they visit bars.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# I love coffee and visiting new coffee shops both locally and while traveling. For my independent study, I chose to look at the influences on someone’s choice to accept a coupon for coffee shops.

# %%
#creating a new dataframe limited to the coffee house coupon 
coffee_data= data.query('coupon =="Coffee House"')
#viewing data
coffee_data.head()
# Out:
#         destination  passanger weather  temperature  time        coupon  \
# 1   No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 3   No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 4   No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 12  No Urgent Place     Kid(s)   Sunny           55   6PM  Coffee House
# 15             Home      Alone   Sunny           80   6PM  Coffee House
#
#    expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 1          2h  Female  21  Unmarried partner  ...        never       NaN
# 3          2h  Female  21  Unmarried partner  ...        never       NaN
# 4          1d  Female  21  Unmarried partner  ...        never       NaN
# 12         2h  Female  21  Unmarried partner  ...        never       NaN
# 15         2h  Female  21  Unmarried partner  ...        never       NaN
#
#    RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
coffee_data['CoffeeHouse'].isnull().sum()
# Out:
# 72

# %%
coffee_data= coffee_data.dropna(subset=['CoffeeHouse'])
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3924 entries, 1 to 12681
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           3924 non-null   object
#  1   passanger             3924 non-null   object
#  2   weather               3924 non-null   object
#  3   temperature           3924 non-null   int64
#  4   time                  3924 non-null   object
#  5   coupon                3924 non-null   object
#  6   expiration            3924 non-null   object
#  7   gender                3924 non-null   object
#  8   age                   3924 non-null   object
#  9   maritalStatus         3924 non-null   object
#  10  has_children          3924 non-null   int64
#  11  education             3924 non-null   object
#  12  occupation            3924 non-null   object
#  13  income                3924 non-null   object
#  14  Bar                   3908 non-null   object
# ...

# %%
#comparing acceptance rate for all coffee coupons 

coffee_total = coffee_data.count()[0]
coffee_yes_counts = coffee_data[coffee_data['Y']==1].count()[0]
print(f'coffee_total: {coffee_total}')
print(f'coffee_yes: {coffee_yes_counts}')
print(f'acceptance rate: {coffee_yes_counts/coffee_total}')
# Out:
# coffee_total: 3924
# coffee_yes: 1962
# acceptance rate: 0.5

# %%
#creating datasets of 
dest_counts = coffee_yes['destination'].value_counts()
weather_counts = coffee_yes['weather'].value_counts()
temp_counts = coffee_yes['temperature'].value_counts()
time_counts = coffee_yes['time'].value_counts()

dest_counts
# Out:
# destination
# No Urgent Place    1228
# Work                402
# Home                332
# Name: count, dtype: int64

# %%
#plotting counts
fig, axes = plt.subplots(1, 4, figsize=(10,5),sharey=False)
fig.suptitle('Comparing the Yes Factor')

#axes[0].set_title('destination')
a = sns.barplot(ax=axes[0], x=dest_counts.index, y=dest_counts.values)
for item in a.get_xticklabels():
    item.set_rotation(45)

    
#axes[1].set_title('weather')
b= sns.barplot(ax=axes[1], x=weather_counts.index, y=weather_counts.values)
for item in b.get_xticklabels():
    item.set_rotation(45)

#axes[2].set_title('temperature')
c= sns.barplot(ax=axes[2], x=temp_counts.index, y=temp_counts.values)
for item in c.get_xticklabels():
    item.set_rotation(45)

#axes[3].set_title('time')
d =sns.barplot(ax=axes[3], x=time_counts.index, y=time_counts.values)
for item in d.get_xticklabels():
    item.set_rotation(45)

fig.tight_layout() 
plt.savefig('images/q7_Yes_Factor_1.png')

# %%
#create a list of columns and their values with a count greater than X
# I used this process to not only learn a little more about pandas but to help provide a list of attributes to use.
filter_dict = {} 
for i in coffee_data.columns:
    if coffee_data[i].dtype !='int64':
            if coffee_data[i].value_counts(ascending=False).values[0] > 2000:
                filter_dict[coffee_data[i].name] = coffee_data[i].value_counts(ascending=False).index[0]
filter_dict
# Out:
# {'destination': 'No Urgent Place',
#  'passanger': 'Alone',
#  'weather': 'Sunny',
#  'coupon': 'Coffee House',
#  'expiration': '2h',
#  'gender': 'Female'}

# %%
q7_dataset1 = coffee_data[
                        (
                          coffee_data['time'].isin(['10AM']) 
                        & coffee_data['temperature'].isin([80]) 
                        & coffee_data['weather'].isin(['Sunny'])
                        & coffee_data['destination'].isin(['No Urgent Place'])
                       )]

q7_1 = q7_dataset1.count()[0]

q7_1Y = q7_dataset1[(q7_dataset1['Y']==1)].count()[0]
q7_1_accept_rate = q7_1Y/q7_1
print(f'The acceptance rate of this population was: {round(q7_1_accept_rate,2)}')
# Out:
# The acceptance rate of this population was: 0.63

# %%
#create a dictionary of columns and their values with a count greater than X
#this list is intended to be the first step in feature identification but will need future exploration
filter_dict = {} 
for i in coffee_data.columns:
    if coffee_data[i].dtype !='int64':
            if coffee_data[i].value_counts(ascending=False).values[0] > 2000:
                filter_dict[coffee_data[i].name] = coffee_data[i].value_counts(ascending=False).index[0]
filter_dict
# Out:
# {'destination': 'No Urgent Place',
#  'passanger': 'Alone',
#  'weather': 'Sunny',
#  'coupon': 'Coffee House',
#  'expiration': '2h',
#  'gender': 'Female'}

# %%
q7_dataset2 = coffee_data[
                    # do not go to bars more than once a month, had passengers that were not a kid, and were not widowed 
                        (
                         coffee_data['gender'].isin(['Female'])                                                    
                        & coffee_data['weather'].isin(['Sunny'])
                        & coffee_data['expiration'].isin(['2h'])
                        & coffee_data['passanger'].isin(['Alone'])
                        & coffee_data['destination'].isin(['No Urgent Place'])
                       )]
q7_2 = q7_dataset2.count()[0]
q7_2Y = q7_dataset2[(q7_dataset2['Y']==1)].count()[0]
q7_2_accept_rate = q7_2Y/q7_2
print(f'The acceptance rate of this population was: {round(q7_2_accept_rate,2)}')
# Out:
# The acceptance rate of this population was: 0.48
